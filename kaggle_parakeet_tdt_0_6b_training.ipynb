# %% [markdown]
# # Parakeet TDT 0.6B — Kaggle-style training (single cell)
#
# **Local:** Run the code cell below from the ASR repo root (same folder as `kaggle_nemo_parakeet_tdt_0.6b_single_cell.py`). Adjust `os.environ` paths for your machine or keep Kaggle paths if mirroring a notebook.
#
# **Kaggle:** Copy the entire contents of `kaggle_nemo_parakeet_tdt_0.6b_single_cell.py` into one notebook cell (or upload that file as a dataset and `exec(open(...).read())`).
#
# **Fix applied:** encoder layer adapters use `infer_encoder_hidden_dim()` (config or dummy forward) so `in_features` matches the real encoder (e.g. 1024), not 512.

# %%
from pathlib import Path
import runpy

script = Path("kaggle_nemo_parakeet_tdt_0.6b_single_cell.py").resolve()
if not script.is_file():
    raise FileNotFoundError(f"Run from repo root; missing {script}")
runpy.run_path(str(script), run_name="__main__")
